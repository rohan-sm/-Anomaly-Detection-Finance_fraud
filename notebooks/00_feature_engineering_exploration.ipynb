# %% [markdown]
# # Feature Engineering for Fraud Detection
#
# This notebook is used to:
# - Understand the dataset
# - Visually validate feature engineering logic
# - Prototype behavioral & velocity-based features
# - Ensure no data leakage before modeling
#
# Final feature logic will live in `src/feature_engineering/`

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# %%
df = pd.read_csv("../data/raw/transactions_raw.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])

print(df.shape)
df.head()
# Out:
# (100000, 15)
#   transaction_id customer_id       card_number                  timestamp   amount     merchant_id merchant_category  \
# 0   TXN_00005946  CUST_00000  73dd02d325d8ba6c 2025-03-08 09:48:00.000000  1044.99  MERCHANT_01868           jewelry
# 1   TXN_00006401  CUST_00000  73dd02d325d8ba6c 2025-03-08 11:15:27.407530  1205.51  MERCHANT_00792           jewelry
# 2   TXN_00009276  CUST_00000  73dd02d325d8ba6c 2025-03-08 22:15:19.130894   127.99  MERCHANT_01036      luxury_goods
# 3   TXN_00012697  CUST_00000  73dd02d325d8ba6c 2025-03-09 07:26:13.375615   423.80  MERCHANT_01430      luxury_goods
# 4   TXN_00019183  CUST_00000  73dd02d325d8ba6c 2025-03-09 11:11:41.342503   644.50  MERCHANT_01181           jewelry
#
#    merchant_lat  merchant_long  distance_from_home  hour  day_of_week  month  is_fraud fraud_type
# 0     19.073305      72.872680                5.62     9            5      3         0       none
# 1     19.055841      72.885882                4.45    11            5      3         0       none
# 2     19.073716      72.885006                4.34    22            5      3         0       none
# 3     19.084250      72.864179                6.72     7            6      3         0       none
# 4     19.089023      72.890843                4.32    11            6      3         0       none

# %%
df.columns
# Out:
# Index(['transaction_id', 'customer_id', 'card_number', 'timestamp', 'amount', 'merchant_id', 'merchant_category',
#        'merchant_lat', 'merchant_long', 'distance_from_home', 'hour', 'day_of_week', 'month', 'is_fraud',
#        'fraud_type'],
#       dtype='object')

# %%
df = df.sort_values(["customer_id", "timestamp"]).reset_index(drop=True)
df.head(10)
# Out:
#   transaction_id customer_id       card_number                  timestamp   amount     merchant_id merchant_category  \
# 0   TXN_00005946  CUST_00000  73dd02d325d8ba6c 2025-03-08 09:48:00.000000  1044.99  MERCHANT_01868           jewelry
# 1   TXN_00006401  CUST_00000  73dd02d325d8ba6c 2025-03-08 11:15:27.407530  1205.51  MERCHANT_00792           jewelry
# 2   TXN_00009276  CUST_00000  73dd02d325d8ba6c 2025-03-08 22:15:19.130894   127.99  MERCHANT_01036      luxury_goods
# 3   TXN_00012697  CUST_00000  73dd02d325d8ba6c 2025-03-09 07:26:13.375615   423.80  MERCHANT_01430      luxury_goods
# 4   TXN_00019183  CUST_00000  73dd02d325d8ba6c 2025-03-09 11:11:41.342503   644.50  MERCHANT_01181           jewelry
# 5   TXN_00025902  CUST_00000  73dd02d325d8ba6c 2025-03-09 22:47:51.166047   572.50  MERCHANT_00313           jewelry
# 6   TXN_00036187  CUST_00000  73dd02d325d8ba6c 2025-03-09 23:16:19.896549   883.36  MERCHANT_01497           grocery
# 7   TXN_00044321  CUST_00000  73dd02d325d8ba6c 2025-03-10 00:50:32.557008   735.52  MERCHANT_01855           jewelry
# 8   TXN_00045931  CUST_00000  73dd02d325d8ba6c 2025-03-10 14:12:03.517317  1378.04  MERCHANT_00495      luxury_goods
# 9   TXN_00055491  CUST_00000  73dd02d325d8ba6c 2025-03-10 21:02:11.504790  1028.46  MERCHANT_00977        restaurant
#
#    merchant_lat  merchant_long  distance_from_home  hour  day_of_week  month  is_fraud fraud_type
# 0     19.073305      72.872680                5.62     9            5      3         0       none
# 1     19.055841      72.885882                4.45    11            5      3         0       none
# 2     19.073716      72.885006                4.34    22            5      3         0       none
# 3     19.084250      72.864179                6.72     7            6      3         0       none
# 4     19.089023      72.890843                4.32    11            6      3         0       none
# 5     19.083504      72.875069                5.59    22            6      3         0       none
# 6     19.094257      72.889192                4.79    23            6      3         0       none
# 7     19.064466      72.884365                4.40     0            0      3         0       none
# 8     19.051227      72.872674                5.93    14            0      3         0       none
# 9     19.084760      72.878279                5.32    21            0      3         0       none

# %%
df["prev_txn_time"] = df.groupby("customer_id")["timestamp"].shift(1)

df["time_since_last_txn_sec"] = (
    df["timestamp"] - df["prev_txn_time"]
).dt.total_seconds()

df[[
    "customer_id",
    "timestamp",
    "prev_txn_time",
    "time_since_last_txn_sec"
]].head(10)

# Fraud often happens in bursts
# Very small gaps = suspicious velocity
# Out:
#   customer_id                  timestamp              prev_txn_time  time_since_last_txn_sec
# 0  CUST_00000 2025-03-08 09:48:00.000000                        NaT                      NaN
# 1  CUST_00000 2025-03-08 11:15:27.407530 2025-03-08 09:48:00.000000              5247.407530
# 2  CUST_00000 2025-03-08 22:15:19.130894 2025-03-08 11:15:27.407530             39591.723364
# 3  CUST_00000 2025-03-09 07:26:13.375615 2025-03-08 22:15:19.130894             33054.244721
# 4  CUST_00000 2025-03-09 11:11:41.342503 2025-03-09 07:26:13.375615             13527.966888
# 5  CUST_00000 2025-03-09 22:47:51.166047 2025-03-09 11:11:41.342503             41769.823544
# 6  CUST_00000 2025-03-09 23:16:19.896549 2025-03-09 22:47:51.166047              1708.730502
# 7  CUST_00000 2025-03-10 00:50:32.557008 2025-03-09 23:16:19.896549              5652.660459
# 8  CUST_00000 2025-03-10 14:12:03.517317 2025-03-10 00:50:32.557008             48090.960309
# 9  CUST_00000 2025-03-10 21:02:11.504790 2025-03-10 14:12:03.517317             24607.987473

# %%
txn_count_1h = (
    df.groupby("customer_id")
      .rolling("1h", on="timestamp")["transaction_id"]
      .count()
      .reset_index(drop=True)
)

df["txn_count_1h"] = txn_count_1h.values

df[[
    "customer_id",
    "timestamp",
    "txn_count_1h"
]].head(15)

# Normal users: 1–2 txns/hour
# Fraud: rapid spikes
# Out:
#    customer_id                  timestamp  txn_count_1h
# 0   CUST_00000 2025-03-08 09:48:00.000000           1.0
# 1   CUST_00000 2025-03-08 11:15:27.407530           1.0
# 2   CUST_00000 2025-03-08 22:15:19.130894           1.0
# 3   CUST_00000 2025-03-09 07:26:13.375615           1.0
# 4   CUST_00000 2025-03-09 11:11:41.342503           1.0
# 5   CUST_00000 2025-03-09 22:47:51.166047           1.0
# 6   CUST_00000 2025-03-09 23:16:19.896549           2.0
# 7   CUST_00000 2025-03-10 00:50:32.557008           1.0
# 8   CUST_00000 2025-03-10 14:12:03.517317           1.0
# 9   CUST_00000 2025-03-10 21:02:11.504790           1.0
# 10  CUST_00000 2025-03-11 22:49:42.246940           1.0
# 11  CUST_00000 2025-03-12 13:04:25.012772           1.0
# 12  CUST_00000 2025-03-12 13:25:27.196036           2.0
# 13  CUST_00000 2025-03-12 18:45:08.040589           1.0
# 14  CUST_00000 2025-03-13 01:26:40.131568           1.0

# %%
txn_count_24h = (
    df.groupby("customer_id")
      .rolling("24h", on="timestamp")["transaction_id"]
      .count()
      .reset_index(drop=True)
)

df["txn_count_24h"] = txn_count_24h.values

df[[
    "customer_id",
    "timestamp",
    "txn_count_24h"
]].head(15)


# Captures daily spending intensity
# Helps separate normal heavy users from bursts
# Out:
#    customer_id                  timestamp  txn_count_24h
# 0   CUST_00000 2025-03-08 09:48:00.000000            1.0
# 1   CUST_00000 2025-03-08 11:15:27.407530            2.0
# 2   CUST_00000 2025-03-08 22:15:19.130894            3.0
# 3   CUST_00000 2025-03-09 07:26:13.375615            4.0
# 4   CUST_00000 2025-03-09 11:11:41.342503            4.0
# 5   CUST_00000 2025-03-09 22:47:51.166047            3.0
# 6   CUST_00000 2025-03-09 23:16:19.896549            4.0
# 7   CUST_00000 2025-03-10 00:50:32.557008            5.0
# 8   CUST_00000 2025-03-10 14:12:03.517317            4.0
# 9   CUST_00000 2025-03-10 21:02:11.504790            5.0
# 10  CUST_00000 2025-03-11 22:49:42.246940            1.0
# 11  CUST_00000 2025-03-12 13:04:25.012772            2.0
# 12  CUST_00000 2025-03-12 13:25:27.196036            3.0
# 13  CUST_00000 2025-03-12 18:45:08.040589            4.0
# 14  CUST_00000 2025-03-13 01:26:40.131568            4.0

# %%
avg_amount_24h = (
    df.groupby("customer_id")
      .rolling("24h", on="timestamp")["amount"]
      .mean()
      .reset_index(drop=True)
)

df["avg_amount_24h"] = avg_amount_24h.values

# add a date-only column for readable display
df["timestamp_date"] = df["timestamp"].dt.date

df[[
    "customer_id",
    "amount",
    "timestamp_date",
    "avg_amount_24h"
]].head(15)


# Fraud is relative, not absolute.
# ₹5,000 is:
# normal for some users
# extreme for others
# Out:
#    customer_id   amount timestamp_date  avg_amount_24h
# 0   CUST_00000  1044.99     2025-03-08     1044.990000
# 1   CUST_00000  1205.51     2025-03-08     1125.250000
# 2   CUST_00000   127.99     2025-03-08      792.830000
# 3   CUST_00000   423.80     2025-03-09      700.572500
# 4   CUST_00000   644.50     2025-03-09      600.450000
# 5   CUST_00000   572.50     2025-03-09      546.933333
# 6   CUST_00000   883.36     2025-03-09      631.040000
# 7   CUST_00000   735.52     2025-03-10      651.936000
# 8   CUST_00000  1378.04     2025-03-10      892.355000
# 9   CUST_00000  1028.46     2025-03-10      919.576000
# 10  CUST_00000   145.21     2025-03-11      145.210000
# 11  CUST_00000   615.16     2025-03-12      380.185000
# 12  CUST_00000   414.93     2025-03-12      391.766667
# 13  CUST_00000   971.68     2025-03-12      536.745000
# 14  CUST_00000   739.62     2025-03-13      685.347500

# %%
df["amount_deviation"] = df["amount"] - df["avg_amount_24h"]

df[[
    "amount",
    "avg_amount_24h",
    "amount_deviation"
]].head(15)

# Positive deviation = unusually large purchase
# Negative deviation = drop (less important) in spending
# Out:
#      amount  avg_amount_24h  amount_deviation
# 0   1044.99     1044.990000          0.000000
# 1   1205.51     1125.250000         80.260000
# 2    127.99      792.830000       -664.840000
# 3    423.80      700.572500       -276.772500
# 4    644.50      600.450000         44.050000
# 5    572.50      546.933333         25.566667
# 6    883.36      631.040000        252.320000
# 7    735.52      651.936000         83.584000
# 8   1378.04      892.355000        485.685000
# 9   1028.46      919.576000        108.884000
# 10   145.21      145.210000          0.000000
# 11   615.16      380.185000        234.975000
# 12   414.93      391.766667         23.163333
# 13   971.68      536.745000        434.935000
# 14   739.62      685.347500         54.272500

# %%
df[[
    "amount",
    "distance_from_home",
    "txn_count_1h",
    "txn_count_24h",
    "time_since_last_txn_sec",
    "amount_deviation",
    "is_fraud"
]].head(20)
# Out:
#      amount  distance_from_home  txn_count_1h  txn_count_24h  time_since_last_txn_sec  amount_deviation  is_fraud
# 0   1044.99                5.62           1.0            1.0                      NaN          0.000000         0
# 1   1205.51                4.45           1.0            2.0             5.247408e+03         80.260000         0
# 2    127.99                4.34           1.0            3.0             3.959172e+04       -664.840000         0
# 3    423.80                6.72           1.0            4.0             3.305424e+04       -276.772500         0
# 4    644.50                4.32           1.0            4.0             1.352797e+04         44.050000         0
# 5    572.50                5.59           1.0            3.0             4.176982e+04         25.566667         0
# 6    883.36                4.79           2.0            4.0             1.708731e+03        252.320000         0
# 7    735.52                4.40           1.0            5.0             5.652660e+03         83.584000         0
# 8   1378.04                5.93           1.0            4.0             4.809096e+04        485.685000         0
# 9   1028.46                5.32           1.0            5.0             2.460799e+04        108.884000         0
# 10   145.21                6.42           1.0            1.0             9.285074e+04          0.000000         0
# 11   615.16                4.75           1.0            2.0             5.128277e+04        234.975000         0
# 12   414.93                5.36           2.0            3.0             1.262183e+03         23.163333         0
# 13   971.68                4.32           1.0            4.0             1.918084e+04        434.935000         0
# 14   739.62                5.72           1.0            4.0             2.409209e+04         54.272500         0
# 15   585.77                5.38           1.0            5.0             7.826679e+03        -79.662000         0
# 16   805.59                4.98           1.0            1.0             9.775262e+04          0.000000         0
# 17   862.71                3.38           1.0            1.0             1.510361e+06          0.000000         0
# 18  3274.92                7.87           1.0            1.0                      NaN          0.000000         0
# 19  2915.25                7.49           1.0            2.0             1.059519e+04       -179.835000         0

# %%
features_df = df.drop(
    columns=[
        "transaction_id",
        "card_number",
        "timestamp",
        "fraud_type"
    ],
    errors="ignore"
)

features_df.head()
# Out:
#   customer_id   amount     merchant_id merchant_category  merchant_lat  merchant_long  distance_from_home  hour  \
# 0  CUST_00000  1044.99  MERCHANT_01868           jewelry     19.073305      72.872680                5.62     9
# 1  CUST_00000  1205.51  MERCHANT_00792           jewelry     19.055841      72.885882                4.45    11
# 2  CUST_00000   127.99  MERCHANT_01036      luxury_goods     19.073716      72.885006                4.34    22
# 3  CUST_00000   423.80  MERCHANT_01430      luxury_goods     19.084250      72.864179                6.72     7
# 4  CUST_00000   644.50  MERCHANT_01181           jewelry     19.089023      72.890843                4.32    11
#
#    day_of_week  month  is_fraud              prev_txn_time  time_since_last_txn_sec  txn_count_1h  txn_count_24h  \
# 0            5      3         0                        NaT                      NaN           1.0            1.0
# 1            5      3         0 2025-03-08 09:48:00.000000              5247.407530           1.0            2.0
# 2            5      3         0 2025-03-08 11:15:27.407530             39591.723364           1.0            3.0
# 3            6      3         0 2025-03-08 22:15:19.130894             33054.244721           1.0            4.0
# 4            6      3         0 2025-03-09 07:26:13.375615             13527.966888           1.0            4.0
#
#    avg_amount_24h timestamp_date  amount_deviation
# 0       1044.9900     2025-03-08            0.0000
# 1       1125.2500     2025-03-08           80.2600
# 2        792.8300     2025-03-08         -664.8400
# 3        700.5725     2025-03-09         -276.7725
# 4        600.4500     2025-03-09           44.0500

# %%
features_df.describe().T
# Out:
#                             count                           mean                  min                            25%  \
# amount                   100000.0                      803.72667                 10.0                         391.57
# merchant_lat             100000.0                        17.2718            10.993044                      12.964056
# merchant_long            100000.0                       76.62344            72.849556                      75.847137
# distance_from_home       100000.0                      69.835448                 2.15                           6.38
# hour                     100000.0                       11.53719                  0.0                            6.0
# day_of_week              100000.0                        3.02965                  0.0                            1.0
# month                    100000.0                        2.05771                  1.0                            1.0
# is_fraud                 100000.0                        0.01038                  0.0                            0.0
# prev_txn_time               95000  2025-02-16 22:45:41.477806592  2025-01-01 00:22:00  2025-01-26 17:38:06.158126592
# time_since_last_txn_sec   95000.0                   50564.118898             0.113564                      8353.0986
# txn_count_1h             100000.0                        1.11976                  1.0                            1.0
# txn_count_24h            100000.0                        3.61228                  1.0                            2.0
# avg_amount_24h           100000.0                     803.875079                 10.0                         424.64
# amount_deviation         100000.0                      -0.148409           -4021.7275                     -90.930625
#
#                                                    50%                            75%                         max  \
# amount                                          640.08                         1019.8                    11167.71
# merchant_lat                                 17.383423                      19.088059                   28.638727
# merchant_long                                76.953742                      77.602789                   80.297143
# distance_from_home                                7.83                            9.4                     1968.31
# hour                                              12.0                           18.0                        23.0
# day_of_week                                        3.0                            5.0                         6.0
# month                                              2.0                            3.0                         3.0
# is_fraud                                           0.0                            0.0                         1.0
# prev_txn_time            2025-02-17 13:04:13.270507008  2025-03-10 02:43:51.572147456  2025-03-31 23:31:56.642329
# time_since_last_txn_sec                   21263.832761                    46315.85315              7437693.815186
# txn_count_1h                                       1.0                            1.0                         5.0
# txn_count_24h                                      3.0                            5.0                        16.0
# avg_amount_24h                               655.97875                     1008.71875                    7391.995
# amount_deviation                                   0.0                      89.493125                 4877.141667
#
#                                    std
# amount                      628.964248
# merchant_lat                  5.393832
# merchant_long                 2.142109
# distance_from_home           258.86262
# hour                           6.91004
# day_of_week                   2.015959
# month                         0.818747
# is_fraud                      0.101353
# prev_txn_time                      NaN
# time_since_last_txn_sec  260683.382479
# txn_count_1h                  0.351225
# txn_count_24h                  2.08011
# avg_amount_24h              569.258922
# amount_deviation            267.484749

# %% [markdown]
# ## Feature engineering --> round 2

# %%
# distance between two points (purchases)
from math import radians, sin, cos, sqrt, atan2
import numpy as np

def haversine_km(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in km

    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    return R * c

# %%
df["prev_lat"] = df.groupby("customer_id")["merchant_lat"].shift(1)
df["prev_long"] = df.groupby("customer_id")["merchant_long"].shift(1)
df["prev_time"] = df.groupby("customer_id")["timestamp"].shift(1)

# %%
df["travel_distance_km"] = df.apply(
    lambda row: haversine_km(
        row["prev_lat"], row["prev_long"],
        row["merchant_lat"], row["merchant_long"]
    ) if pd.notna(row["prev_lat"]) else 0,
    axis=1
)

# %%
df["time_diff_hours"] = (
    (df["timestamp"] - df["prev_time"]).dt.total_seconds() / 3600
)

# %%
df["travel_speed_kmh"] = df["travel_distance_km"] / df["time_diff_hours"]

# %%
# Handle first txn and very small gaps
df["travel_speed_kmh"] = df["travel_speed_kmh"].replace([np.inf, -np.inf], np.nan)
df["travel_speed_kmh"] = df["travel_speed_kmh"].fillna(0)

# Optional: cap extreme GPS noise
df["travel_speed_kmh"] = df["travel_speed_kmh"].clip(upper=20000)

# %%
df["travel_speed_kmh"].describe()
# Out:
# count    100000.000000
# mean         81.041161
# std         760.629263
# min           0.000000
# 25%           0.144031
# 50%           0.428247
# 75%           1.831808
# max       20000.000000
# Name: travel_speed_kmh, dtype: float64

# %%
# Cyclical Hour Encoding

df["hour_sin"] = np.sin(2 * np.pi * df["hour"] / 24)
df["hour_cos"] = np.cos(2 * np.pi * df["hour"] / 24)

df[["hour", "hour_sin", "hour_cos"]].head(10)
# Out:
#    hour  hour_sin  hour_cos
# 0     9  0.707107 -0.707107
# 1    11  0.258819 -0.965926
# 2    22 -0.500000  0.866025
# 3     7  0.965926 -0.258819
# 4    11  0.258819 -0.965926
# 5    22 -0.500000  0.866025
# 6    23 -0.258819  0.965926
# 7     0  0.000000  1.000000
# 8    14 -0.500000 -0.866025
# 9    21 -0.707107  0.707107

# %%
df[["hour", "hour_sin", "hour_cos"]].sample(20)
# Out:
#        hour      hour_sin  hour_cos
# 63778    23 -2.588190e-01  0.965926
# 59906    15 -7.071068e-01 -0.707107
# 54293     5  9.659258e-01  0.258819
# 811      14 -5.000000e-01 -0.866025
# 28725     5  9.659258e-01  0.258819
# 53866     9  7.071068e-01 -0.707107
# 80575    23 -2.588190e-01  0.965926
# 26719     4  8.660254e-01  0.500000
# 48238    23 -2.588190e-01  0.965926
# 32445    10  5.000000e-01 -0.866025
# 35055    12  1.224647e-16 -1.000000
# 55580     1  2.588190e-01  0.965926
# 16668     4  8.660254e-01  0.500000
# 77944    17 -9.659258e-01 -0.258819
# 91557     9  7.071068e-01 -0.707107
# 82108    17 -9.659258e-01 -0.258819
# 5683     13 -2.588190e-01 -0.965926
# 92380     2  5.000000e-01  0.866025
# 64056     7  9.659258e-01 -0.258819
# 59092     7  9.659258e-01 -0.258819
